# %%
#Reading CSV Files With csv

# %%
import csv

# %%
with open('Customer_Data.txt') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0] + row[1]} {row[2]} is a {row[4]}, has IP Address {row[-2]} and lives at province {row[10]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are prefix, first, last, email, gender, age, company, profession, phone, postal, province, cc_no, cc_exp, cc_type, price(CAD), fav_color, ip, weekday
# 	Dr.Ray Morton is a Male, has IP Address 126.23.139.2 and lives at province MB.
# 	Miss.Claudia Rodriquez is a Female, has IP Address 106.198.76.211 and lives at province SK.
# 	Miss.Harry Meyer is a Female, has IP Address 186.150.187.29 and lives at province NS.
# 	Miss.Edith Gilbert is a Female, has IP Address 80.140.57.161 and lives at province YT.
# 	Dr.Lura Murphy is a Female, has IP Address 211.103.43.41 and lives at province ON.
# 	Mrs.Andre McGuire is a Male, has IP Address 44.6.228.222 and lives at province AB.
# 	Mr.Cody Thompson is a Female, has IP Address 46.87.230.156 and lives at province PE.
# 	Mr.Cory Duncan is a Male, has IP Address 209.5.235.14 and lives at province NU.
# 	Miss.Dorothy Watkins is a Female, has IP Address 11.57.253.20 and lives at province MB.
# ...

# %%
#Reading CSV Files Into a Dictionary With csv

# %%
with open('Customer_Data.txt', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        print(f'\t{row["first"]} {row["last"]} works for the {row["company"]}, as a {row["profession"]}.')
        line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are prefix, first, last, email, gender, age, company, profession, phone, postal, province, cc_no, cc_exp, cc_type, price(CAD), fav_color, ip, weekday
# 	Ray Morton works for the Medtronic Inc., as a Health Therapist.
# 	Claudia Rodriquez works for the Ames Department Stores, Inc., as a Health Therapist.
# 	Harry Meyer works for the CSX Corp., as a Political Scientist.
# 	Edith Gilbert works for the Murphy Oil Corporation, as a Transportation Manager.
# 	Lura Murphy works for the PETsMART Inc, as a Statistician.
# 	Andre McGuire works for the Timken Company, as a Communications Director.
# 	Cody Thompson works for the Nicor Inc, as a Special Education Teacher.
# 	Cory Duncan works for the Integrated Electrical Services Inc., as a Urban Planner.
# 	Dorothy Watkins works for the Service Corp. International, as a Veterinarian.
# 	Rose Tate works for the Eastman Kodak Company, as a Software Engineer.
# Processed 11 lines.

# %%
import pandas as pd

# %%
df = pd.read_csv('Cust_Purch_Data.csv')
df.head()
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province         cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5.020000e+15  05/2018                       Solo
# ...

# %%
df["name"] = df["first"] + " " + df["last"]
df.head()
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province         cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5.020000e+15  05/2018                       Solo
# ...

# %%
df.columns
# Out:
# Index(['prefix', 'first', 'last', 'email', 'gender', 'age', 'company',
#        'profession', 'phone', 'postal', 'province', 'cc_no', 'cc_exp',
#        'cc_type', 'price(CAD)', 'fav_color', 'ip', 'weekday', 'name'],
#       dtype='object')

# %%
df = df[['name','email', 'gender', 'age', 'company',
       'profession', 'phone', 'postal', 'province', 'cc_no', 'cc_exp',
       'cc_type', 'price(CAD)', 'fav_color', 'ip', 'weekday']]
df.head()
# Out:
#                 name              email  gender  age  \
# 0         Ray Morton    sebvajom@kol.km    Male   38
# 1  Claudia Rodriquez      acu@jatsot.ug  Female   51
# 2        Harry Meyer          zuz@lo.wf  Female   51
# 3      Edith Gilbert  hansohsi@jupec.md  Female   55
# 4        Lura Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province         cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5.020000e+15  05/2018                       Solo
# ...

# %%
parse_dates=['cc_exp']
df.head()
# Out:
#                 name              email  gender  age  \
# 0         Ray Morton    sebvajom@kol.km    Male   38
# 1  Claudia Rodriquez      acu@jatsot.ug  Female   51
# 2        Harry Meyer          zuz@lo.wf  Female   51
# 3      Edith Gilbert  hansohsi@jupec.md  Female   55
# 4        Lura Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province         cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5.020000e+15  05/2018                       Solo
# ...

# %%
print(type(df['cc_exp'][0]))
# Out:
# <class 'str'>

# %%
df['cc_exp'] = pd.to_datetime(df['cc_exp'])
df['cc_exp'].dt.date
print(type(df['cc_exp'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
import sys

# %%
print ("The script has the name %s" % (sys.argv[0]))
# Out:
# The script has the name C:\Users\Vadim\anaconda3\lib\site-packages\ipykernel_launcher.py

# %%
arguments = len(sys.argv) - 1
print ("The script is called with %i arguments" % (arguments))
# Out:
# The script is called with 2 arguments

# %%
position = 1
while (arguments >= position):
    print ("Parameter %i: %s" % (position, sys.argv[position]))
    position = position + 1
# Out:
# Parameter 1: -f
# Parameter 2: C:\Users\Vadim\AppData\Roaming\jupyter\runtime\kernel-92967c21-ae5b-4ebc-84ad-415a8af6d2b4.json

# %%
# Include standard modules
import getopt

# Get full command-line arguments
full_cmd_arguments = sys.argv

# Keep all but the first
argument_list = full_cmd_arguments[1:]

print(argument_list)
# Out:
# ['-f', 'C:\\Users\\Vadim\\AppData\\Roaming\\jupyter\\runtime\\kernel-92967c21-ae5b-4ebc-84ad-415a8af6d2b4.json']

# %%
short_options = "ho:v"
long_options = ["help", "output=", "verbose"]
